# %%
import pandas as pd
import re
import csv
import os
import sys
from collections import Counter
import collections
import numpy as np

print(np.__version__)
# Out:
# 1.26.4

# %%
#script for SNPs
#dir_list1 = os.listdir("/media/sf_BGI_RNA-seq/parapsilosis_genotyping/different_ref/perSVade/annotate_small_vars/")
dir_list1 = []
dir_list2 = os.listdir("/media/davideisele/Windows/Users/q027de.I-MED/Desktop/BGI_RNA-seq/parapsilosis_genotyping/different_ref/perSVade/annotate_small_vars/")
#dir_list2 = os.listdir("/media/sf_D_DRIVE/SRA_outbreak/perSVade_outbreak/Bergin_outbreaks/snv_annotated2/")
#dir_list2 = os.listdir("/media/sf_D_DRIVE/SRA_outbreak/perSVade_outbreak/Bergin_outbreaks/snv_annotated3/")
dir_list = dir_list1 + dir_list2
#dir_list = os.listdir("/media/sf_D_DRIVE/SRA_outbreak/perSVade_outbreak/snv_annotated/")

#dir_list
df_dict = {}
set_dict = {}
for item in dir_list:
    if item != "ignore" and item in dir_list1:
        #print(item)
        try:
            #cp = pd.read_csv("/media/sf_D_DRIVE/SRA_outbreak/perSVade_outbreak/Bergin_outbreaks/snv_annotated2/" + item + 
             #                "/annotated_variants.tab", delimiter="\t")
            #cp = pd.read_csv("/media/sf_D_DRIVE/SRA_outbreak/perSVade_outbreak/Bergin_outbreaks/snv_annotated3/" + item + 
             #                "/annotated_variants.tab", delimiter="\t")
            cp = pd.read_csv("/media/davideisele/Windows/Users/q027de.I-MED/Desktop/BGI_RNA-seq/parapsilosis_genotyping/different_ref/perSVade/annotate_small_vars/" + item + 
                             "/pass3/annotated_variants.tab", delimiter="\t")
            #cp = pd.read_csv("/media/sf_D_DRIVE/SRA_outbreak/perSVade_outbreak/snv_annotated/" + item + 
             #               "/pass3/annotated_variants.tab", delimiter="\t")
            #cp = pd.read_csv("/home/davideisele/perSVade_para/annotate_small_vars/" + item + "/pass3/annotated_variants.tab", delimiter="\t")
            #cp = cp[cp['is_protein_altering'] == True] #reactivate
            cp = cp[cp['is_snp'] == True] #reactivate
            #cp = cp[cp['Protein_position'] != '-']
            #print(item)
            #print(cp[cp['#Uploaded_variation'] == 'NW_023503283.1_1412160_C/T'])
            df_dict[item] = cp
            set_dict[item] = set(cp['#Uploaded_variation'])
        except Exception:
            #print(item)
            pass
    if item != "ignore" and item in dir_list2:
        try:
            cp = pd.read_csv("/media/sf_D_DRIVE/SRA_outbreak/perSVade_outbreak/snv_annotated/" + item + 
                             "/pass3/annotated_variants.tab", delimiter="\t")
            #cp = pd.read_csv("/media/sf_D_DRIVE/SRA_outbreak/perSVade_outbreak/Bergin_outbreaks/snv_annotated3/" + item + 
             #                "/annotated_variants.tab", delimiter="\t")
            cp = cp[cp['is_snp'] == True]
            #cp = cp[cp['Protein_position'] != '-']
            df_dict[item] = cp
            set_dict[item] = set(cp['#Uploaded_variation'])
        except Exception:
            print(item)
            pass
set_dict
#df_dict
#dir_list
#dir_list2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 4
#       1 #script for SNPs
#       2 #dir_list1 = os.listdir("/media/sf_BGI_RNA-seq/parapsilosis_genotyping/different_ref/perSVade/annotate_small_vars/")
#       3 dir_list1 = []
# ----> 4 dir_list2 = os.listdir("/media/sf_D_DRIVE/SRA_outbreak/perSVade_outbreak/snv_annotated/")
#       5 #dir_list2 = os.listdir("/media/sf_D_DRIVE/SRA_outbreak/perSVade_outbreak/Bergin_outbreaks/snv_annotated2/")
#       6 #dir_list2 = os.listdir("/media/sf_D_DRIVE/SRA_outbreak/perSVade_outbreak/Bergin_outbreaks/snv_annotated3/")
#       7 dir_list = dir_list1 + dir_list2
#
# FileNotFoundError: [Errno 2] No such file or directory: '/media/sf_D_DRIVE/SRA_outbreak/perSVade_outbreak/snv_annotated/'

# %%
dict1 = {}
for key1, value1 in set_dict.items():
    dict2= {}
    for key2, value2 in set_dict.items():
        dict2[key2] = len(value1.symmetric_difference(value2))
        #dict2[key2] = len(value1.difference(value2))
        #dict2[key2] = [len(value1.difference(value2)), len(value2.difference(value1))]
    dict1[key1] = dict2
#print(dict1)

# %%
df = pd.json_normalize([{'index': k, **v} for k, v in dict1.items()])
#print(df)
df = df.set_index('index')
#df['NG-A4501_CP19_libLAN2875']
#df1 = df['NG-A4501_CR6_libLAN2918']
#df1 = df1[df1 <= 731]
cutoff = df.max().max()
cutoff
#df[['NG-A4501_CP17_libLAN2873', 'NG-A4501_CP54_libLAN2909', 'NG-A4501_CP54_libLAN2909', 'NG-A4501_CP30_libLAN2885', 'NG-A4501_CP3_libLAN2861']]
#df1 = df.loc[['NG-A4501_CP19_libLAN2875', 'NG-A4501_CP1_libLAN2859', 'NG-A4501_CP20_libLAN2876', 'NG-A4501_CP22_libLAN2878', 'NG-A4501_CP63_libLAN2916'],['NG-A4501_CP19_libLAN2875', 'NG-A4501_CP1_libLAN2859', 'NG-A4501_CP20_libLAN2876', 'NG-A4501_CP22_libLAN2878', 'NG-A4501_CP63_libLAN2916']]
df = df.replace(0, np.NaN)
df.max().max()
print(df.min().min())
# Out:
# 28.0

# %%
#find minimal distance between clusters

#cluster1
#df1 = df.loc[['NG-A4501_CP19_libLAN2875', 'NG-A4501_CP1_libLAN2859', 'NG-A4501_CP20_libLAN2876', 'NG-A4501_CP22_libLAN2878', 'NG-A4501_CP63_libLAN2916'],['NG-A4501_CP19_libLAN2875', 'NG-A4501_CP1_libLAN2859', 'NG-A4501_CP20_libLAN2876', 'NG-A4501_CP22_libLAN2878', 'NG-A4501_CP63_libLAN2916']]

#cluster2
#df1 = df.loc[['NG-A4501_CP17_libLAN2873', 'NG-A4501_CP44_libLAN2899', 'NG-A4501_CP54_libLAN2909'],['NG-A4501_CP17_libLAN2873', 'NG-A4501_CP44_libLAN2899', 'NG-A4501_CP54_libLAN2909']]

#cluster3
#df1 = df.loc[['NG-A4501_CP21_libLAN2877', 'NG-A4501_CP29_libLAN2884', 'NG-A4501_CP35_libLAN2890', 'NG-A4501_CP36_libLAN2891', 'NG-A4501_CP37_libLAN2892',
 #                            'NG-A4501_CP38_libLAN2893', 'NG-A4501_CP39_libLAN2894', 'NG-A4501_CP42_libLAN5089', 'NG-A4501_CP45_libLAN2900', 'NG-A4501_CP46_libLAN2901',
  #                           'NG-A4501_CP47_libLAN2902', 'NG-A4501_CP48_libLAN2903', 'NG-A4501_CP51_libLAN2906', 'NG-A4501_CP52_libLAN2907', 'NG-A4501_CP53_libLAN2908',
   #                          'NG-A4501_CP58_libLAN2911', 'NG-A4501_CP59_libLAN2912', 'NG-A4501_CP60_libLAN2913'], ['NG-A4501_CP21_libLAN2877', 'NG-A4501_CP29_libLAN2884', 'NG-A4501_CP35_libLAN2890', 'NG-A4501_CP36_libLAN2891', 'NG-A4501_CP37_libLAN2892',
    #                         'NG-A4501_CP38_libLAN2893', 'NG-A4501_CP39_libLAN2894', 'NG-A4501_CP42_libLAN5089', 'NG-A4501_CP45_libLAN2900', 'NG-A4501_CP46_libLAN2901',
     #                        'NG-A4501_CP47_libLAN2902', 'NG-A4501_CP48_libLAN2903', 'NG-A4501_CP51_libLAN2906', 'NG-A4501_CP52_libLAN2907', 'NG-A4501_CP53_libLAN2908',
      #                       'NG-A4501_CP58_libLAN2911', 'NG-A4501_CP59_libLAN2912', 'NG-A4501_CP60_libLAN2913']]

#cluster4
#df1 = df.loc[['NG-A4501_CP40_libLAN2895', 'NG-A4501_CP41_libLAN2896'],['NG-A4501_CP40_libLAN2895', 'NG-A4501_CP41_libLAN2896']]

#cluster5
#df1 = df.loc[['NG-A4501_CP33_libLAN2888', 'NG-A4501_CP55_libLAN2910', 'NG-A4501_CP64_libLAN2917'],['NG-A4501_CP33_libLAN2888', 'NG-A4501_CP55_libLAN2910', 'NG-A4501_CP64_libLAN2917']]

#cluster6
df1 = df.loc[['NG-A4501_CP10_libLAN2866', 'NG-A4501_CP11_libLAN2867', 'NG-A4501_CP12_libLAN2868', 'NG-A4501_CP14_libLAN2870', 'NG-A4501_CP27_libLAN2882', 'NG-A4501_CP6_libLAN2863', 'NG-A4501_CP9_libLAN2865'],
['NG-A4501_CP10_libLAN2866', 'NG-A4501_CP11_libLAN2867', 'NG-A4501_CP12_libLAN2868', 'NG-A4501_CP14_libLAN2870', 'NG-A4501_CP27_libLAN2882', 'NG-A4501_CP6_libLAN2863', 'NG-A4501_CP9_libLAN2865']]

#df1 = df.loc[['SRR28395726','SRR28395727','SRR28395737','SRR28395738','SRR28395739','SRR28395740','SRR28395744','SRR28395745','SRR28395746','SRR28395747','SRR28395748','SRR28395749','SRR28395762','SRR28395763'],['NG-A4501_CP19_libLAN2875', 'NG-A4501_CP1_libLAN2859', 'NG-A4501_CP20_libLAN2876', 'NG-A4501_CP22_libLAN2878', 'NG-A4501_CP63_libLAN2916']]
  #                           'NG-A4501_CP58_libLAN2911', 'NG-A4501_CP59_libLAN2912', 'NG-A4501_CP60_libLAN2913'], ['NG-A4501_CP40_libLAN2895', 'NG-A4501_CP41_libLAN2896', 'NG-A4501_CP21_libLAN2877', 'NG-A4501_CP29_libLAN2884', 'NG-A4501_CP35_libLAN2890', 'NG-A4501_CP36_libLAN2891', 'NG-A4501_CP37_libLAN2892','NG-A4501_CP38_libLAN2893', 'NG-A4501_CP39_libLAN2894', 'NG-A4501_CP42_libLAN5089', 'NG-A4501_CP45_libLAN2900', 'NG-A4501_CP46_libLAN2901',
   #                          'NG-A4501_CP47_libLAN2902', 'NG-A4501_CP48_libLAN2903', 'NG-A4501_CP51_libLAN2906', 'NG-A4501_CP52_libLAN2907', 'NG-A4501_CP53_libLAN2908',
    #                         'NG-A4501_CP58_libLAN2911', 'NG-A4501_CP59_libLAN2912', 'NG-A4501_CP60_libLAN2913']]
#df1 = df.loc[['NG-A4501_CP10_libLAN2866', 'NG-A4501_CP11_libLAN2867', 'NG-A4501_CP12_libLAN2868', 'NG-A4501_CP14_libLAN2870', 'NG-A4501_CP27_libLAN2882', 
 #                             'NG-A4501_CP6_libLAN2863', 'NG-A4501_CP9_libLAN2865'],['NG-A4501_CP10_libLAN2866', 'NG-A4501_CP11_libLAN2867', 'NG-A4501_CP12_libLAN2868', 'NG-A4501_CP14_libLAN2870', 'NG-A4501_CP27_libLAN2882', 
  #                            'NG-A4501_CP6_libLAN2863', 'NG-A4501_CP9_libLAN2865']]


df1 = df1.replace(0, np.NaN)
#print(df1)
print(df1.min().min())
print(df1.mean().mean())
print(df1.max().max())
# Out:
# 61.0
# 283.6190476190476
# 448.0

# %%
df_filtered = df[df < 731] #cutoffs: outbreak1=731 ; bergin2=537 ; bergin3=310 #cutoff(protein_altering): 1: 314, 2: 206, 3: 119
#df_filtered.dropna(axis = 0, how = 'all')
df_filtered2 = df_filtered[~df_filtered.iloc[:, 1:].fillna('nan').isin([0, 'nan']).all(axis=1)]
df_filtered3 = df_filtered2.dropna(axis=1, how='all')
#df_filtered4 = df_filtered3[['NG-A4501_CP17_libLAN2873', 'NG-A4501_CP44_libLAN2899', 'NG-A4501_CP54_libLAN2909']]
#df_filtered4 = df_filtered3.loc[['NG-A4501_CP19_libLAN2875', 'NG-A4501_CP1_libLAN2859', 'NG-A4501_CP20_libLAN2876', 'NG-A4501_CP22_libLAN2878', 'NG-A4501_CP63_libLAN2916'],
#['NG-A4501_CP19_libLAN2875', 'NG-A4501_CP1_libLAN2859', 'NG-A4501_CP20_libLAN2876', 'NG-A4501_CP22_libLAN2878', 'NG-A4501_CP63_libLAN2916']]
df_filtered4 = df_filtered3.loc[['NG-A4501_CP21_libLAN2877', 'NG-A4501_CP29_libLAN2884', 'NG-A4501_CP35_libLAN2890', 'NG-A4501_CP36_libLAN2891', 'NG-A4501_CP37_libLAN2892',
                             'NG-A4501_CP38_libLAN2893', 'NG-A4501_CP39_libLAN2894', 'NG-A4501_CP42_libLAN5089', 'NG-A4501_CP45_libLAN2900', 'NG-A4501_CP46_libLAN2901',
                             'NG-A4501_CP47_libLAN2902', 'NG-A4501_CP48_libLAN2903', 'NG-A4501_CP51_libLAN2906', 'NG-A4501_CP52_libLAN2907', 'NG-A4501_CP53_libLAN2908',
                             'NG-A4501_CP58_libLAN2911', 'NG-A4501_CP59_libLAN2912', 'NG-A4501_CP60_libLAN2913'], ['NG-A4501_CP21_libLAN2877', 'NG-A4501_CP29_libLAN2884', 'NG-A4501_CP35_libLAN2890', 'NG-A4501_CP36_libLAN2891', 'NG-A4501_CP37_libLAN2892',
                             'NG-A4501_CP38_libLAN2893', 'NG-A4501_CP39_libLAN2894', 'NG-A4501_CP42_libLAN5089', 'NG-A4501_CP45_libLAN2900', 'NG-A4501_CP46_libLAN2901',
                             'NG-A4501_CP47_libLAN2902', 'NG-A4501_CP48_libLAN2903', 'NG-A4501_CP51_libLAN2906', 'NG-A4501_CP52_libLAN2907', 'NG-A4501_CP53_libLAN2908',
                             'NG-A4501_CP58_libLAN2911', 'NG-A4501_CP59_libLAN2912', 'NG-A4501_CP60_libLAN2913']]
#df_filtered4 = df_filtered3[['NG-A4501_CP40_libLAN2895', 'NG-A4501_CP41_libLAN2896']]
#df_filtered4 = df_filtered3[['NG-A4501_CP10_libLAN2866', 'NG-A4501_CP11_libLAN2867', 'NG-A4501_CP12_libLAN2868', 'NG-A4501_CP14_libLAN2870', 'NG-A4501_CP27_libLAN2882', 
 #                             'NG-A4501_CP6_libLAN2863', 'NG-A4501_CP9_libLAN2865']]
#df_filtered4 = df_filtered3[['NG-A4501_CP33_libLAN2888', 'NG-A4501_CP55_libLAN2910', 'NG-A4501_CP64_libLAN2917']]

#df_filtered4 = df_filtered3[['NG-A4501_CP17_libLAN2873', 'NG-A4501_CP30_libLAN2885', 'NG-A4501_CP3_libLAN2861', 'NG-A4501_CP44_libLAN2899', 'NG-A4501_CP54_libLAN2909']]
#df_filtered4 = df_filtered3[['NG-A4501_CP40_libLAN2895', 'NG-A4501_CP41_libLAN2896']]
#df_filtered4 = df_filtered3[['NG-A4501_CP55_libLAN2910', 'NG-A4501_CP64_libLAN2917', 'NG-A4501_CP33_libLAN2888']]

#df_filtered4 = df_filtered3[['NG-A4501_CP40_libLAN2895', 'NG-A4501_CP60_libLAN2913']]
#df_filtered4 = df_filtered3[['NG-A4501_CP21_libLAN2877']]
#df_filtered5 = df_filtered4[~df_filtered4.iloc[:, 1:].fillna('nan').isin(['nan']).all(axis=1)]
#df_filtered5
df_filtered4.max().max()
#df_filtered4
# Out:
# 261.0

# %%
df_filtered3['NG-A4501_CP30_libLAN2885']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NG-A4501_CP30_libLAN2885'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[419], line 1
# ----> 1 df_filtered3['NG-A4501_CP30_libLAN2885']
#
# ...
